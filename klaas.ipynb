# %%
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
#from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt
# %matplotlib inline 
from PIL import Image

import numpy as np
from tqdm import tqdm
# Out:
# 2024-02-19 13:49:23.124214: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-19 13:49:23.199768: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-19 13:49:23.199850: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-19 13:49:23.202626: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-19 13:49:23.215653: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-19 13:49:24.754792: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Каталог с данными для обучения
train_dir = 'DATASET/train'
# Каталог с данными для проверки
val_dir = 'DATASET/validation'
# Каталог с данными для тестирования
test_dir = 'DATASET/test'
# Размеры изображения
img_width, img_height = 512, 256
# Размерность тензора на основе изображения для входных данных в нейронную сеть
# backend Tensorflow, channels_last
input_shape = (img_width, img_height, 1)
# Размер мини-выборки
batch_size = 64

# %%
image_file_name = train_dir + '/1/3.jpeg' # with watermark
img = Image.open(image_file_name)
plt.imshow(img)

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255,)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 74040 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

val_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 24680 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 24680 images belonging to 2 classes.

# %%
# Deep Learning
model = Sequential()

model.add(Conv2D(filters=8, kernel_size=(5, 5), padding="same" , activation="relu", input_shape=(img_width,img_height,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(5, 5)))

model.add(Conv2D(filters=16, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(MaxPooling2D(pool_size=(5, 5)))

model.add(Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(5, 5)))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='sigmoid')) # 'softmax'

# %%
input_shape = (None, 512, 256, 3)
model.build(input_shape) # `input_shape` is the shape of the input data
                         # e.g. input_shape = (None, 32, 32, 3)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 512, 256, 8)       608
#
#  batch_normalization (Batch  (None, 512, 256, 8)       32
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 102, 51, 8)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 102, 51, 16)       3216
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 10, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 10, 64)        25664
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 2, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 2048)              8390656
#
#  dense_2 (Dense)             (None, 1024)              2098176
#
#  dense_3 (Dense)             (None, 512)               524800
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 13210322 (50.39 MB)
# Trainable params: 13210306 (50.39 MB)
# Non-trainable params: 16 (64.00 Byte)
# _________________________________________________________________

# %%
#Binary cross entropy of each label. So no really a binary classification problem but
#Calculating binary cross entropy for each label. 
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Обучаем модель с использованием генераторов
# train_generator - генератор данных для обучения
# validation_data - генератор данных для проверки

# Need to run with real data to infer shape of different layers
history = model.fit(train_generator,
    steps_per_epoch=2,
    epochs=50,
    validation_data=val_generator,
    validation_steps=1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.3750
# Epoch 2/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6940 - accuracy: 0.3750 - val_loss: 0.6934 - val_accuracy: 0.3125
# Epoch 3/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6932 - accuracy: 0.3438 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6930 - accuracy: 0.5625 - val_loss: 0.6923 - val_accuracy: 0.6250
# Epoch 5/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6939 - accuracy: 0.4375 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6923 - accuracy: 0.5938 - val_loss: 0.6943 - val_accuracy: 0.3750
# Epoch 7/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6928 - accuracy: 0.5625 - val_loss: 0.6924 - val_accuracy: 0.5625
# Epoch 8/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6901 - accuracy: 0.6562 - val_loss: 0.6969 - val_accuracy: 0.3125
# Epoch 9/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6919 - accuracy: 0.5312 - val_loss: 0.6914 - val_accuracy: 0.5625
# Epoch 10/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6926 - accuracy: 0.5312 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 11/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6920 - accuracy: 0.5312 - val_loss: 0.6965 - val_accuracy: 0.4375
# Epoch 12/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6910 - accuracy: 0.5312 - val_loss: 0.6971 - val_accuracy: 0.4375
# Epoch 13/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6876 - accuracy: 0.5938 - val_loss: 0.7056 - val_accuracy: 0.3750
# Epoch 14/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6862 - accuracy: 0.5625 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 15/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6871 - accuracy: 0.5938 - val_loss: 0.6625 - val_accuracy: 0.6875
# Epoch 16/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6670 - accuracy: 0.5938 - val_loss: 0.6855 - val_accuracy: 0.5625
# Epoch 17/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.7455 - accuracy: 0.5000 - val_loss: 0.7220 - val_accuracy: 0.3750
# Epoch 18/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6679 - accuracy: 0.6250 - val_loss: 0.7031 - val_accuracy: 0.4375
# Epoch 19/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6843 - accuracy: 0.5625 - val_loss: 0.6947 - val_accuracy: 0.5000
# Epoch 20/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6979 - accuracy: 0.5000 - val_loss: 0.6898 - val_accuracy: 0.5625
# Epoch 21/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.7015 - accuracy: 0.4062 - val_loss: 0.6966 - val_accuracy: 0.4375
# Epoch 22/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6971 - accuracy: 0.4375 - val_loss: 0.6880 - val_accuracy: 0.6875
# Epoch 23/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6944 - accuracy: 0.4375 - val_loss: 0.6959 - val_accuracy: 0.3125
# Epoch 24/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6937 - accuracy: 0.4062 - val_loss: 0.6929 - val_accuracy: 0.5625
# Epoch 25/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6927 - accuracy: 0.5938 - val_loss: 0.6939 - val_accuracy: 0.4375
# Epoch 26/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6951 - accuracy: 0.4375 - val_loss: 0.6896 - val_accuracy: 0.6875
# Epoch 27/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6931 - accuracy: 0.5312 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 28/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6929 - accuracy: 0.5000 - val_loss: 0.6903 - val_accuracy: 0.6250
# Epoch 29/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6925 - accuracy: 0.5625 - val_loss: 0.6905 - val_accuracy: 0.6250
# Epoch 30/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6910 - accuracy: 0.5938 - val_loss: 0.6950 - val_accuracy: 0.4375
# Epoch 31/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6923 - accuracy: 0.5312 - val_loss: 0.6907 - val_accuracy: 0.5625
# Epoch 32/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6867 - accuracy: 0.6250 - val_loss: 0.6901 - val_accuracy: 0.5625
# Epoch 33/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.7005 - accuracy: 0.4688 - val_loss: 0.6894 - val_accuracy: 0.5625
# Epoch 34/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6926 - accuracy: 0.5000 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 35/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6879 - accuracy: 0.5625 - val_loss: 0.6983 - val_accuracy: 0.4375
# Epoch 36/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6986 - accuracy: 0.4688 - val_loss: 0.6897 - val_accuracy: 0.5625
# Epoch 37/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6885 - accuracy: 0.5625 - val_loss: 0.6940 - val_accuracy: 0.5000
# Epoch 38/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6863 - accuracy: 0.5938 - val_loss: 0.6892 - val_accuracy: 0.5625
# Epoch 39/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.7019 - accuracy: 0.4375 - val_loss: 0.6833 - val_accuracy: 0.6250
# Epoch 40/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6988 - val_accuracy: 0.4375
# Epoch 41/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.6981 - accuracy: 0.4375 - val_loss: 0.6892 - val_accuracy: 0.5625
# Epoch 42/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6975 - accuracy: 0.4375 - val_loss: 0.7031 - val_accuracy: 0.3125
# Epoch 43/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.6957 - accuracy: 0.4375 - val_loss: 0.6910 - val_accuracy: 0.5625
# Epoch 44/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6918 - accuracy: 0.5625 - val_loss: 0.6879 - val_accuracy: 0.6875
# Epoch 45/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6968 - accuracy: 0.3750 - val_loss: 0.6946 - val_accuracy: 0.4375
# Epoch 46/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6920 - accuracy: 0.5312 - val_loss: 0.6856 - val_accuracy: 0.8750
# Epoch 47/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6922 - accuracy: 0.5625 - val_loss: 0.6952 - val_accuracy: 0.3750
# Epoch 48/50
# 2/2 [==============================] - 3s 2s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6913 - val_accuracy: 0.6250
# Epoch 49/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6922 - accuracy: 0.5312 - val_loss: 0.6965 - val_accuracy: 0.3125
# Epoch 50/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6940 - accuracy: 0.4688 - val_loss: 0.6887 - val_accuracy: 0.7500

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'orange', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['val_accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'blue', label='Training acc')
plt.plot(epochs, val_acc, 'o', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
scores = model.evaluate(test_generator)
print("\nТочность на тестовых данных: %.2f%%" % (scores[1]*100))
# Out:
# 1360/1543 [=========================>....] - ETA: 46s - loss: 0.6932 - accuracy: 0.5000
